# %% [markdown]
# Q1

# %%
import sys
print("Python is installed.")
print("Version:", sys.version)
# Out:
# Python is installed.
# Version: 3.13.12 (tags/v3.13.12:1cbe481, Feb  3 2026, 18:22:25) [MSC v.1944 64 bit (AMD64)]

# %% [markdown]
# Q2

# %%
# 2(a)
print("Hello Everyone !!!")

# 2(b)
print("Hello")
print("World")

# 2(c)
print("Hello\nWorld")   # \n adds a new line

# 2(d)
print("Rohit's date of birth is 12\\05\\1999")  # double backslash to avoid escape sequence issues
# Out:
# Hello Everyone !!!
# Hello
# World
# Hello
# World
# Rohit's date of birth is 12\05\1999

# %% [markdown]
# Q3

# %%
x = "Hello"
print(x)
# Out:
# Hello

# %% [markdown]
# Q4

# %%
integer_value = 10
float_value = 3.14
string_value = "Python"
boolean_value = True
list_value = [1, 2, 3]

print("Integer:", integer_value)
print("Float:", float_value)
print("String:", string_value)
print("Boolean:", boolean_value)
print("List:", list_value)
# Out:
# Integer: 10
# Float: 3.14
# String: Python
# Boolean: True
# List: [1, 2, 3]

# %% [markdown]
# Q5

# %%
a = "Rohit"
b = "Sharma"
full_name = a + " " + b
print("Full Name:", full_name)
# Out:
# Full Name: Rohit Sharma

# %% [markdown]
# Q6

# %%
first_name = "George"
last_name = "Washington"
nickname = "woody"

print(f"{first_name} ({nickname}) {last_name}")
# Out:
# George (woody) Washington

# %% [markdown]
# Q7

# %%
name = "NIKUNJ BANSAL"
sap_id = "500069944"
dob = "13 Oct 1999"
address_line1 = "UPES"
address_line2 = "Bidholi Campus"
pincode = "248007"
programme = "AI & ML"
semester = 2

print("NAME:", name)
print("SAP ID:", sap_id)
print("DATE OF BIRTH:", dob)
print("ADDRESS:", address_line1)
print(address_line2)
print("Pincode:", pincode)
print("Programme:", programme)
print("Semester:", semester)
# Out:
# NAME: NIKUNJ BANSAL
# SAP ID: 500069944
# DATE OF BIRTH: 13 Oct 1999
# ADDRESS: UPES
# Bidholi Campus
# Pincode: 248007
# Programme: AI & ML
# Semester: 2
